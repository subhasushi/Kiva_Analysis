# %%
import pandas as pd
import collections

import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as p3

from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

import seaborn as sns

import pickle

import json

import requests

n_clusters = 4

# %%
plt.style.use('seaborn')

# %%
loans_samples_reduced = pd.read_csv('final_reduced_dataset.csv')

# %%
loans_samples_reduced = loans_samples_reduced.set_index('loan_id')

# %%
loans_samples_reduced['borrower_count'] = loans_samples_reduced['female_count']+loans_samples_reduced['male_count']

# %%
# Stratified Sampling by country and sectors

loans_samples = loans_samples_reduced.groupby(['sector_name'], group_keys=False).apply(lambda x: x.sample(min(len(x), 1200)))

loans_samples = loans_samples.reset_index(drop=True)

loans_samples.shape
# Out:
# (17663, 20)

# %%
def getFeatureVector(dataset):
    
    X = dataset[['loan_amount', 'status', 'activity_name', 'sector_name','borrower_count','mpi', 'population_in_mpi',
                 'Education', 'Health', 'Living standards', 'population_in_severe_mpi']]

    dataset_dummies = pd.get_dummies(X)

    scaler = StandardScaler()

    scaler.fit(dataset_dummies)

    data_scaled = scaler.transform(dataset_dummies)

    feature = pd.DataFrame(data_scaled)

    feature.columns = dataset_dummies.columns
    
    return feature

# %%
features_df = getFeatureVector(loans_samples)

features_df.head()
# Out:
#    loan_amount  borrower_count       mpi  population_in_mpi  Education  \
# 0     0.547952       -0.234785 -0.984597          -1.031705  -0.390979
# 1     1.213323       -0.234785  0.325591           0.454933  -1.595794
# 2    -0.893684       -0.234785 -0.828415          -0.912037   0.856484
# 3    -0.228313       -0.234785 -0.741648          -0.723331  -0.838786
# 4    -0.893684       -0.234785 -0.845769          -0.838396  -1.478511
#
#      Health  Living standards  population_in_severe_mpi  status_funded  \
# 0  1.104516         -0.763529                 -0.907544            0.0
# 1  0.100467          1.406167                 -0.086896            0.0
# 2 -0.096405         -0.713071                 -0.609858            0.0
# 3 -0.135779          0.931861                 -0.778815            0.0
# 4  2.108564         -0.763529                 -0.851225            0.0
#
#    activity_name_Agriculture          ...            \
# 0                  -0.095610          ...
# 1                  -0.095610          ...
# 2                  -0.095610          ...
# 3                  10.459147          ...
# 4                  -0.095610          ...
#
#    sector_name_Entertainment  sector_name_Food  sector_name_Health  \
# 0                  -0.244976         -0.269983           -0.269983
# 1                  -0.244976         -0.269983           -0.269983
# 2                  -0.244976         -0.269983           -0.269983
# 3                  -0.244976         -0.269983           -0.269983
# 4                  -0.244976         -0.269983           -0.269983
#
#    sector_name_Housing  sector_name_Manufacturing  sector_name_Personal Use  \
# 0            -0.269983                  -0.269983                 -0.269983
# 1            -0.269983                  -0.269983                 -0.269983
# 2            -0.269983                  -0.269983                 -0.269983
# 3            -0.269983                  -0.269983                 -0.269983
# 4            -0.269983                  -0.269983                 -0.269983
#
#    sector_name_Retail  sector_name_Services  sector_name_Transportation  \
# 0           -0.269983             -0.269983                   -0.269983
# 1           -0.269983             -0.269983                   -0.269983
# 2           -0.269983             -0.269983                   -0.269983
# 3           -0.269983             -0.269983                   -0.269983
# 4           -0.269983             -0.269983                   -0.269983
#
#    sector_name_Wholesale
# 0              -0.253054
# 1              -0.253054
# 2              -0.253054
# 3              -0.253054
# 4              -0.253054
#
# [5 rows x 177 columns]

# %%
def applyPCA(n,features):
    pca = PCA(n_components=n) #n-dimensional PCA
    principal_df = pd.DataFrame(pca.fit_transform(features))
    
    # Identifying the significant features of final PCA components
    
    PCA_stats = pd.DataFrame(pca.components_,columns=features.columns,index = range(0,n)).transpose()
    print(f"PCA transformation applied with {n} components:")
    print("\nTop 5 features in each principal component")
    print([PCA_stats[c].nlargest(5) for c in PCA_stats])
    print('-----------------------------------------------')
    
    return principal_df

# %%
applyPCA(3,features_df)
# Out:
# PCA transformation applied with 3 components:
#
# Top 5 features in each principal component
# [population_in_mpi           0.496289
# mpi                         0.492841
# population_in_severe_mpi    0.466181
# Living standards            0.265984
# borrower_count              0.138023
# Name: 0, dtype: float64, sector_name_Personal Use         0.415705
# activity_name_Home Appliances    0.358683
# Education                        0.289617
# borrower_count                   0.202237
# sector_name_Retail               0.145191
# Name: 1, dtype: float64, sector_name_Personal Use         0.388646
# activity_name_Home Appliances    0.331599
# borrower_count                   0.259153
# sector_name_Health               0.226786
# sector_name_Agriculture          0.211701
# Name: 2, dtype: float64]
# -----------------------------------------------
#               0         1         2
# 0     -1.834063 -0.399516  1.770135
# 1      0.760933 -1.146928  1.789988
# 2     -1.944190  1.254566  1.245309
# 3     -1.164410  0.139653  1.734821
# 4     -1.926766 -0.141020  2.463653
# 5     -1.968301 -0.076171  1.844168
# 6      0.010518  0.879111  1.005470
# 7     -2.296601 -0.395067  2.114404
# 8      0.125723 -0.803253  1.943208
# 9      0.677424 -0.560864  2.052157
# 10     1.212347 -0.019655  0.967240
# 11    -1.748248  0.782918  1.370630
# 12    -0.229783  0.800444  1.251337
# 13    -1.160720  0.191333  1.748573
# 14    -1.707346  1.262050  1.175794
# 15     1.878851  0.381286  1.748294
# 16    -3.864583 -1.024984  2.509916
# 17     0.797831 -0.630132  1.927507
# 18     1.865937  0.200407  1.700162
# 19    -1.988595 -0.360409  1.768533
# 20    -1.904814  0.932045  1.357256
# 21    -2.046828  0.828904  1.550842
# 22    -1.951569  1.151207  1.217805
# 23     1.877006  0.355446  1.741418
# 24    -0.027092  0.659263  1.619519
# 25    -1.948905 -0.451097  2.381142
# 26    -1.953414  1.125367  1.210929
# 27    -1.179169 -0.067065  1.679813
# 28    -1.697596  0.794579  1.422887
# 29    -2.260904  0.032095  1.809963
# ...         ...       ...       ...
# 17633  1.310973 -1.541726 -0.666624
# 17634 -1.163003 -0.524187 -0.808975
# 17635 -1.333806 -1.690358 -0.406397
# 17636 -1.274004 -1.104139 -0.796706
# 17637  3.767290 -1.363399 -0.788306
# 17638  0.698611 -0.183953 -1.502371
# 17639  0.711525 -0.003074 -1.454240
# 17640  1.746155 -0.687878 -1.151796
# 17641  1.746155 -0.687878 -1.151796
# 17642  0.743683 -0.002822 -1.481958
# 17643  3.728546 -1.906035 -0.932701
# 17644  1.778313 -0.687626 -1.179514
# 17645  3.692699 -1.957967 -0.918734
# 17646  1.757224 -0.532839 -1.110541
# 17647 -0.814128 -0.328292 -0.733640
# 17648 -0.207823 -0.970994 -0.837254
# 17649 -0.448023  0.027587 -1.157034
# 17650 -1.312717 -1.845144 -0.475371
# 17651  0.759264 -1.017899 -1.003289
# 17652 -0.679332  0.097622 -1.066891
# 17653  2.432014 -1.046195 -1.084944
# 17654  1.309128 -1.567566 -0.673500
# 17655  1.322043 -1.386687 -0.625368
# 17656  2.420945 -1.201234 -1.126200
# 17657  1.743259 -1.178582 -1.310157
# 17658 -1.302442 -1.251081 -0.289506
# 17659  1.008451 -0.279233 -1.012517
# 17660 -1.168538 -0.601707 -0.829602
# 17661  0.999226 -0.408432 -1.046896
# 17662  0.958638 -0.976908 -1.198167
#
# [17663 rows x 3 columns]

# %%
# Assuming 3 components on PCA - plot the clusters

def plotClusters(n,transformed):
    
    colors = ['#2f7ed8', '#0d233a', '#8bbc21', '#910000', '#1aadce', '#492970', '#f28f43', '#77a1e5', '#c42525', '#a6c96a']
    
    
    
    for i in range(n): 
        
        plt.title('View in pair of 2 Dimensions')
        
        ax = plt.subplot(1,3,1)
        ax.scatter(transformed[transformed['y']==i][0],  
                   transformed[transformed['y']==i][1],  
                   label=f'Class {i}', 
                   c=colors[i])
        ax = plt.subplot(1,3,2)
        ax.scatter(transformed[transformed['y']==i][1],  
                   transformed[transformed['y']==i][2],  
                   label=f'Class {i}', 
                   c=colors[i])
        ax = plt.subplot(1,3,3)
        ax.scatter(transformed[transformed['y']==i][0],  
                   transformed[transformed['y']==i][2],  
                   label=f'Class {i}', 
                   c=colors[i])
   
    
    fig = plt.figure(figsize=(8,8))
    ax = p3.Axes3D(fig)
    
    for i in range(n):
        ax.scatter(transformed[transformed['y']==i][0],  
                   transformed[transformed['y']==i][2], 
                   transformed[transformed['y']==i][1],  
                   label=f'Class {i}', 
                   c=colors[i])
        
    plt.title('View in 3 Dimensions')
    
    
    plt.legend()
    plt.show()

# %%
# Sticking with 3 component PCA to help visualize the clusters

pca_transformed = applyPCA(3,features_df)

all_cluster_stats = pd.DataFrame()
# Out:
# PCA transformation applied with 3 components:
#
# Top 5 features in each principal component
# [population_in_mpi           0.496072
# mpi                         0.492635
# population_in_severe_mpi    0.465979
# Living standards            0.266706
# borrower_count              0.137701
# Name: 0, dtype: float64, sector_name_Personal Use                   0.363879
# activity_name_Home Appliances              0.317664
# Education                                  0.302044
# sector_name_Housing                        0.191697
# activity_name_Personal Housing Expenses    0.189791
# Name: 1, dtype: float64, sector_name_Personal Use         0.437550
# activity_name_Home Appliances    0.366117
# borrower_count                   0.258750
# sector_name_Health               0.176768
# Health                           0.174442
# Name: 2, dtype: float64]
# -----------------------------------------------

# %%
k_silhouette_scores = []

k_interia_scores = []

for k in range(2,10):
    
    kmeans = KMeans(n_clusters=k, random_state=0).fit(pca_transformed)

    label = kmeans.labels_

    print(f"\nCluster sizes of {k} clusters: \n\t {collections.Counter(label)}")
   
    silhouette_avg = silhouette_score(pca_transformed, label)
    inertia_value = (kmeans.inertia_/k)
    
    k_silhouette_scores.append(silhouette_avg)
    k_interia_scores.append(inertia_value)
    
    print("\nThe average silhouette_score is :", silhouette_avg,
          "\nThe mean intra cluster distance is :", inertia_value)
# Out:
# Cluster sizes of 2 clusters:
# 	 Counter({1: 9495, 0: 8168})
#
# The average silhouette_score is : 0.307447686861
# The mean intra cluster distance is : 50990.4761468
#
# Cluster sizes of 3 clusters:
# 	 Counter({0: 9584, 1: 6829, 2: 1250})
#
# The average silhouette_score is : 0.364324445599
# The mean intra cluster distance is : 24773.7440526
#
# Cluster sizes of 4 clusters:
# 	 Counter({3: 7069, 2: 6565, 0: 2781, 1: 1248})
#
# The average silhouette_score is : 0.400120656812
# The mean intra cluster distance is : 12742.9909142
#
# Cluster sizes of 5 clusters:
# 	 Counter({0: 5771, 3: 5718, 1: 2489, 4: 2448, 2: 1237})
#
# The average silhouette_score is : 0.354024699936
# The mean intra cluster distance is : 8450.79687623
#
# Cluster sizes of 6 clusters:
# 	 Counter({0: 5545, 1: 3556, 5: 3164, 4: 2180, 2: 1981, 3: 1237})
#
# The average silhouette_score is : 0.348071873843
# The mean intra cluster distance is : 6049.00352952
#
# Cluster sizes of 7 clusters:
# 	 Counter({0: 3412, 2: 3199, 6: 3135, 1: 3123, 5: 1940, 4: 1631, 3: 1223})
#
# The average silhouette_score is : 0.332211159956
# The mean intra cluster distance is : 4491.96263637
#
# Cluster sizes of 8 clusters:
# 	 Counter({4: 3289, 1: 3101, 7: 2512, 5: 2448, 3: 2083, 0: 1535, 2: 1475, 6: 1220})
#
# The average silhouette_score is : 0.33698988755
# The mean intra cluster distance is : 3515.24065811
#
# Cluster sizes of 9 clusters:
# 	 Counter({6: 3163, 3: 2845, 0: 2393, 1: 2091, 4: 2050, 5: 1796, 2: 1219, 8: 1181, 7: 925})
#
# The average silhouette_score is : 0.330828116506
# The mean intra cluster distance is : 2867.21005138

# %%
plt.figure(figsize=(15, 8))
ax1 = plt.subplot(1, 1, 1)

ax1.plot(range(2,10),k_silhouette_scores,marker='o',color='blue', label='Silhouette scores')

ax1.set_xlabel('N clusters')
ax1.set_ylabel('Silhouette scores')
ax1.tick_params('y', colors='b')


ax2 = ax1.twinx()

ax2.plot(range(2,10),k_interia_scores,marker='o',color='red', label='Intra cluster mean distance')
ax2.set_ylabel('Intra cluster mean distance', )

plt.title('\nIdentifying Ideal number of Clusters\n')

plt.savefig('Identifying_optimal_K.png')


plt.legend()
plt.show()

# %%
# Sticking with 3 component PCA to help visualize the clusters

def applyKMeansClustering(k,loan_samples):
    
    train_samples, test_samples = train_test_split(loans_samples,random_state=30)

    train_featured = getFeatureVector(train_samples)

    test_featured = getFeatureVector(test_samples)

    pca_transformed_train = applyPCA(3,train_featured)
    pca_transformed_test = applyPCA(3,test_featured)

    pca_clustered_train = pca_transformed_train
    
    pca_clustered_test = pca_transformed_test

    kmeans = KMeans(n_clusters=n_clusters, random_state=42).fit(pca_transformed_train)

    label = kmeans.labels_
    predicted = kmeans.predict(pca_transformed_test)
    
    
    pca_clustered_train['y'] = label
    
    pca_clustered_test['y'] = predicted
    
    print('\nTraining Sample')
    
    plotClusters(k,pca_clustered_train)
    
    print('\nTest Sample')
    
    plotClusters(k,pca_clustered_test)
    
    # Get train & test class info

    train_samples_clustered = train_samples
    test_samples_clustered = test_samples
    
    train_samples_clustered['class'] = label
    test_samples_clustered['class'] =  predicted
    
    print('\nTraining Sample - Describing categorical')
    
    print('\n-----------------------------------------------')
    
    plot_categorical(train_samples_clustered)
    
    
    print('\nTest Sample - Describing categorical')
    
    print('\n-----------------------------------------------')
    
    plot_categorical(test_samples_clustered)
    
    print('\nTraining Sample - Numerical categorical')
    
    print('\n-----------------------------------------------')
    
    plot_numerical(train_samples_clustered)
    
    
    print('\nTest Sample - Numerical categorical')
    
    print('\n-----------------------------------------------')
    
    plot_numerical(test_samples_clustered)
    
    list_pickle_path = f'Kiva_{k}_Clusters.pkl'
    list_pickle = open(list_pickle_path, 'wb')

    pickle.dump(kmeans, list_pickle)
    list_pickle.close()
    
    return train_samples_clustered.append(test_samples_clustered)


loan_samples_clustered = applyKMeansClustering(n_clusters,loans_samples) 

loan_samples_clustered.to_csv('Clustered_samples_dataset.csv')
# Out:
# PCA transformation applied with 3 components:
#
# Top 5 features in each principal component
# [population_in_mpi           0.498258
# mpi                         0.494763
# population_in_severe_mpi    0.467941
# Living standards            0.268463
# borrower_count              0.137799
# Name: 0, dtype: float64, sector_name_Personal Use                   0.345887
# Education                                  0.320867
# activity_name_Home Appliances              0.301512
# sector_name_Housing                        0.216929
# activity_name_Personal Housing Expenses    0.213720
# Name: 1, dtype: float64, sector_name_Personal Use         0.479905
# activity_name_Home Appliances    0.391717
# borrower_count                   0.265453
# Health                           0.179981
# activity_name_Home Energy        0.177287
# Name: 2, dtype: float64]
# -----------------------------------------------
# PCA transformation applied with 3 components:
#
# Top 5 features in each principal component
# [population_in_mpi           0.486878
# mpi                         0.483900
# population_in_severe_mpi    0.458426
# Living standards            0.257738
# borrower_count              0.138246
# Name: 0, dtype: float64, sector_name_Personal Use                   0.343090
# Education                                  0.331427
# activity_name_Home Appliances              0.300313
# borrower_count                             0.181257
# activity_name_Personal Housing Expenses    0.147633
# Name: 1, dtype: float64, sector_name_Personal Use                0.461289
# activity_name_Home Appliances           0.389116
# borrower_count                          0.294190
# sector_name_Education                   0.197119
# activity_name_Higher education costs    0.168001
# Name: 2, dtype: float64]
# -----------------------------------------------
#
# Training Sample
# Test Sample
# C:\Users\ssank\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ssank\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Training Sample - Describing categorical
#
# -----------------------------------------------
# Test Sample - Describing categorical
#
# -----------------------------------------------
# Training Sample - Numerical categorical
#
# -----------------------------------------------
# Test Sample - Numerical categorical
#
# -----------------------------------------------

# %%
def getLatestLoans():
    response = requests.get('http://api.kivaws.org/v1/loans/newest.json').json()
    loan_items = response['loans']

    new_loans_dictionary = []

    for loan in loan_items:
        new_item = {
            'loan_amount': loan['loan_amount'],
            'status': loan['status'],
            'activity_name': loan['activity'],
            'sector_name': loan['sector'],
            'borrower_count': loan['borrower_count'],
            'country_name': loan['location']['country'].lower()
        }

        new_loans_dictionary.append(new_item)

    new_loans_df = pd.DataFrame(new_loans_dictionary)

    new_loans_df = new_loans_df.rename(columns={'country_name':'country'})

    mpi = pd.read_csv('mpi.csv',encoding='latin-1')

    mpi_reduced = mpi[['country','mpi','population_in_mpi','Education','Health','Living standards','population_in_severe_mpi']]
    mpi_reduced.to_csv('mpi.csv',encoding='utf-8')

    merged = new_loans_df.merge(mpi_reduced,on='country')

    return merged

# %%
getLatestLoans()
# Out:
#                 activity_name  borrower_count      country  loan_amount  \
# 0                   Livestock               1   kyrgyzstan          900
# 1                     Farming               1     cambodia         1000
# 2   Personal Housing Expenses               1    indonesia           50
# 3                Fish Selling               1  philippines          400
# 4               General Store               1  philippines          400
# 5               Internet Cafe               1  philippines          400
# 6              Clothing Sales               1        kenya          300
# 7                     Farming               1        kenya          400
# 8         Fruits & Vegetables               1        kenya          300
# 9               Cheese Making               1    nicaragua          400
# 10               Animal Sales               1      ecuador          525
# 11        Fruits & Vegetables               1     pakistan          525
# 12                  Livestock               1       jordan         1275
#
#     sector_name       status    mpi  population_in_mpi  Education  Health  \
# 0   Agriculture  fundraising  0.008                2.2       13.0    73.5
# 1   Agriculture  fundraising  0.150               33.8       30.8    26.4
# 2       Housing  fundraising  0.024                5.9       24.7    35.1
# 3          Food  fundraising  0.033                6.3       35.3    30.2
# 4        Retail  fundraising  0.033                6.3       35.3    30.2
# 5      Services  fundraising  0.033                6.3       35.3    30.2
# 6      Clothing  fundraising  0.166               36.0       12.3    32.2
# 7   Agriculture  fundraising  0.166               36.0       12.3    32.2
# 8          Food  fundraising  0.166               36.0       12.3    32.2
# 9          Food  fundraising  0.088               19.4       37.8    12.6
# 10  Agriculture  fundraising  0.015                3.7       23.6    42.4
# 11         Food  fundraising  0.237               45.6       36.2    32.3
# 12  Agriculture  fundraising  0.004                1.2       31.5    65.0
#
#     Living standards  population_in_severe_mpi
# 0               13.5                       0.0
# 1               42.8                      11.4
# 2               40.2                       1.1
# 3               34.5                       4.2
# 4               34.5                       4.2
# 5               34.5                       4.2
# 6               55.5                      10.7
# 7               55.5                      10.7
# 8               55.5                      10.7
# 9               49.6                       6.9
# 10              34.0                       0.5
# 11              31.6                      26.5
# 12               3.5                       0.1

# %%
def describe_numerical(df):
    stats = pd.DataFrame()
        
    for k in range(n_clusters):  

        kth_cluster = df[df['class']==k]
        
        kth_stats = df[['loan_amount','female_count', 
                          'male_count','population_in_mpi',
                          'lender_term', 'num_lenders_total', 
                          'posted_raised_hours','num_journal_entries'
                       ]].describe().transpose()
        
    stats = stats.append(kth_stats)   
        
    return stats[['mean','50%']]

# %%
def describe_categorical(df):

    cluster_frequency = []

    for k in range(n_clusters):
        kth_cluster = df[df['class']==k]

        category_values = {
            str(k) : {}
        }

        for c in ['country','sector_name','activity_name','status']:
            cat_values = kth_cluster[c].value_counts().head(10).to_dict()
            category_values[str(k)].update({str(c):cat_values})

        cluster_frequency.append(category_values)
        
    return cluster_frequency

# %%
describe_numerical(loan_samples_clustered)
# Out:
#                            mean    50%
# loan_amount          426.470588  400.0
# female_count           0.922946    1.0
# male_count             0.313367    0.0
# population_in_mpi     26.115728   19.4
# lender_term           12.579686   12.0
# num_lenders_total     13.222782   12.0
# posted_raised_hours  235.019363  149.0
# num_journal_entries    1.496631    1.0

# %%
describe_categorical(loan_samples_clustered)
# Out:
# [{'0': {'activity_name': {'Construction': 251,
#     'Crafts': 279,
#     'Entertainment': 262,
#     'Furniture Making': 264,
#     'Games': 305,
#     'General Store': 566,
#     'Manufacturing': 307,
#     'Motorcycle Transport': 396,
#     'Personal Housing Expenses': 938,
#     'Weaving': 292},
#    'country': {'Cambodia': 422,
#     'Colombia': 415,
#     'Ecuador': 133,
#     'Ghana': 117,
#     'Honduras': 106,
#     'Indonesia': 154,
#     'Mexico': 263,
#     'Nicaragua': 648,
#     'Peru': 1016,
#     'Philippines': 3502},
#    'sector_name': {'Agriculture': 473,
#     'Arts': 728,
#     'Construction': 684,
#     'Entertainment': 732,
#     'Food': 677,
#     'Housing': 994,
#     'Manufacturing': 651,
#     'Retail': 901,
#     'Services': 393,
#     'Transportation': 732},
#    'status': {'funded': 7219}}},
#  {'1': {'activity_name': {'Clothing Sales': 481,
#     'Embroidery': 238,
#     'Farming': 250,
#     'Goods Distribution': 407,
#     'Manufacturing': 224,
#     'Personal Housing Expenses': 186,
#     'Primary/secondary school costs': 263,
#     'Tailoring': 225,
#     'Used Clothing': 189,
#     'Wholesale': 292},
#    'country': {'Cambodia': 268,
#     'India': 325,
#     'Kenya': 1686,
#     'Mozambique': 162,
#     'Nicaragua': 156,
#     'Nigeria': 287,
#     'Pakistan': 1304,
#     'Sierra Leone': 201,
#     'Togo': 158,
#     'Uganda': 748},
#    'sector_name': {'Agriculture': 438,
#     'Arts': 455,
#     'Clothing': 794,
#     'Construction': 481,
#     'Education': 391,
#     'Food': 505,
#     'Manufacturing': 512,
#     'Services': 702,
#     'Transportation': 439,
#     'Wholesale': 699},
#    'status': {'funded': 6418}}},
#  {'2': {'activity_name': {'Clothing Sales': 317,
#     'Goods Distribution': 110,
#     'Health': 102,
#     'Higher education costs': 675,
#     'Medical Clinic': 59,
#     'Natural Medicines': 113,
#     'Personal Medical Expenses': 583,
#     'Pharmacy': 68,
#     'Primary/secondary school costs': 78,
#     'Wholesale': 78},
#    'country': {'Armenia': 108,
#     'Cambodia': 77,
#     'Ecuador': 113,
#     'Jordan': 163,
#     'Kenya': 140,
#     'Mexico': 181,
#     'Nicaragua': 122,
#     'Peru': 365,
#     'Philippines': 310,
#     'Tajikistan': 825},
#    'sector_name': {'Agriculture': 235,
#     'Clothing': 330,
#     'Construction': 35,
#     'Education': 809,
#     'Food': 18,
#     'Health': 951,
#     'Manufacturing': 37,
#     'Services': 105,
#     'Transportation': 29,
#     'Wholesale': 188},
#    'status': {'funded': 2778}}},
#  {'3': {'activity_name': {'Agriculture': 3,
#     'Consumer Goods': 32,
#     'Farm Supplies': 1,
#     'Farming': 50,
#     'Funerals': 1,
#     'Home Appliances': 692,
#     'Home Energy': 200,
#     'Personal Expenses': 215,
#     'Vehicle': 46,
#     'Wedding Expenses': 7},
#    'country': {'Cambodia': 645,
#     'Honduras': 15,
#     'Indonesia': 16,
#     'Kenya': 147,
#     "Lao People's Democratic Republic": 42,
#     'Nicaragua': 30,
#     'Nigeria': 96,
#     'Peru': 38,
#     'Philippines': 95,
#     'Tajikistan': 28},
#    'sector_name': {'Agriculture': 54, 'Clothing': 1, 'Personal Use': 1193},
#    'status': {'funded': 1248}}}]

# %%
def plot_numerical(df):
    for c in ['loan_amount','female_count', 'male_count','population_in_mpi',
              'lender_term', 'num_lenders_total', 'posted_raised_hours','num_journal_entries']:

        plt.figure(figsize=(15,10))

        sns.boxplot(x="class", y=c, data=df, palette="Paired")

        plt.title(f'Cluster differences of {c}')

        plt.savefig(f'Cluster_numerical_{c}.png')

        plt.show()
    
    stats = pd.DataFrame()

# %%
def plot_categorical(df):

    for k in range(n_clusters):
        kth_cluster = df[df['class']==k]

        for c in ['country','sector_name','activity_name','status']:
            plt.figure(figsize=(20,5))
            cat_values = kth_cluster[c].value_counts().head(10).to_dict()
            kth_cluster[c].value_counts().head(10).plot(kind='barh')
            
            plt.title(f'Cluster number: {k} - Top 10 in {c}')
            plt.savefig(f'cluster_category_{c}.png')
            plt.show()

# %%
plot_categorical(loan_samples_clustered)

# %%
plot_numerical(loan_samples_clustered)

# %%
merged_ds = getLatestLoans()

# %%
getFeatureVector(merged_ds)
# Out:
#     loan_amount  borrower_count       mpi  population_in_mpi  Education  \
# 0      1.158830             0.0 -1.023695          -1.017909  -1.320945
# 1      1.471054             0.0  0.830811           0.972367   0.462408
# 2     -1.495071             0.0 -0.814737          -0.784870  -0.148741
# 3     -0.402288             0.0 -0.697198          -0.759677   0.913255
# 4     -0.402288             0.0 -0.697198          -0.759677   0.913255
# 5     -0.402288             0.0 -0.697198          -0.759677   0.913255
# 6     -0.714512             0.0  1.039769           1.110930  -1.391077
# 7     -0.402288             0.0  1.039769           1.110930  -1.391077
# 8     -0.714512             0.0  1.039769           1.110930  -1.391077
# 9     -0.402288             0.0  0.021097           0.065406   1.163726
# 10    -0.012009             0.0 -0.932276          -0.923434  -0.258948
# 11    -0.012009             0.0  1.967022           1.715571   1.003425
# 12     2.329669             0.0 -1.075935          -1.080892   0.532540
#
#       Health  Living standards  population_in_severe_mpi  status_fundraising  \
# 0   2.402465         -1.578936                 -1.001509                 0.0
# 1  -0.655808          0.362997                  0.625943                 0.0
# 2  -0.090904          0.190676                 -0.844474                 0.0
# 3  -0.409068         -0.187107                 -0.401921                 0.0
# 4  -0.409068         -0.187107                 -0.401921                 0.0
# 5  -0.409068         -0.187107                 -0.401921                 0.0
# 6  -0.279205          1.204723                  0.526012                 0.0
# 7  -0.279205          1.204723                  0.526012                 0.0
# 8  -0.279205          1.204723                  0.526012                 0.0
# 9  -1.551862          0.813685                 -0.016472                 0.0
# 10  0.383096         -0.220246                 -0.930129                 0.0
# 11 -0.272712         -0.379312                  2.781603                 0.0
# 12  1.850547         -2.241712                 -0.987233                 0.0
#
#     activity_name_Animal Sales          ...           \
# 0                    -0.288675          ...
# 1                    -0.288675          ...
# 2                    -0.288675          ...
# 3                    -0.288675          ...
# 4                    -0.288675          ...
# 5                    -0.288675          ...
# 6                    -0.288675          ...
# 7                    -0.288675          ...
# 8                    -0.288675          ...
# 9                    -0.288675          ...
# 10                    3.464102          ...
# 11                   -0.288675          ...
# 12                   -0.288675          ...
#
#     activity_name_General Store  activity_name_Internet Cafe  \
# 0                     -0.288675                    -0.288675
# 1                     -0.288675                    -0.288675
# 2                     -0.288675                    -0.288675
# 3                     -0.288675                    -0.288675
# 4                      3.464102                    -0.288675
# 5                     -0.288675                     3.464102
# 6                     -0.288675                    -0.288675
# 7                     -0.288675                    -0.288675
# 8                     -0.288675                    -0.288675
# 9                     -0.288675                    -0.288675
# 10                    -0.288675                    -0.288675
# 11                    -0.288675                    -0.288675
# 12                    -0.288675                    -0.288675
#
#     activity_name_Livestock  activity_name_Personal Housing Expenses  \
# 0                  2.345208                                -0.288675
# 1                 -0.426401                                -0.288675
# 2                 -0.426401                                 3.464102
# 3                 -0.426401                                -0.288675
# 4                 -0.426401                                -0.288675
# 5                 -0.426401                                -0.288675
# 6                 -0.426401                                -0.288675
# 7                 -0.426401                                -0.288675
# 8                 -0.426401                                -0.288675
# 9                 -0.426401                                -0.288675
# 10                -0.426401                                -0.288675
# 11                -0.426401                                -0.288675
# 12                 2.345208                                -0.288675
#
#     sector_name_Agriculture  sector_name_Clothing  sector_name_Food  \
# 0                  1.264911             -0.288675         -0.666667
# 1                  1.264911             -0.288675         -0.666667
# 2                 -0.790569             -0.288675         -0.666667
# 3                 -0.790569             -0.288675          1.500000
# 4                 -0.790569             -0.288675         -0.666667
# 5                 -0.790569             -0.288675         -0.666667
# 6                 -0.790569              3.464102         -0.666667
# 7                  1.264911             -0.288675         -0.666667
# 8                 -0.790569             -0.288675          1.500000
# 9                 -0.790569             -0.288675          1.500000
# 10                 1.264911             -0.288675         -0.666667
# 11                -0.790569             -0.288675          1.500000
# 12                 1.264911             -0.288675         -0.666667
#
#     sector_name_Housing  sector_name_Retail  sector_name_Services
# 0             -0.288675           -0.288675             -0.288675
# 1             -0.288675           -0.288675             -0.288675
# 2              3.464102           -0.288675             -0.288675
# 3             -0.288675           -0.288675             -0.288675
# 4             -0.288675            3.464102             -0.288675
# 5             -0.288675           -0.288675              3.464102
# 6             -0.288675           -0.288675             -0.288675
# 7             -0.288675           -0.288675             -0.288675
# 8             -0.288675           -0.288675             -0.288675
# 9             -0.288675           -0.288675             -0.288675
# 10            -0.288675           -0.288675             -0.288675
# 11            -0.288675           -0.288675             -0.288675
# 12            -0.288675           -0.288675             -0.288675
#
# [13 rows x 25 columns]
