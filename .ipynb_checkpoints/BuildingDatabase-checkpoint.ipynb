# %%
import pandas as pd

# %%
loans = pd.read_csv('cleaned_loans.csv')

# %%
# Import SQL Alchemy
from sqlalchemy import create_engine

# Import and establish Base for which classes will be constructed
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# Import modules to declare columns and column data types
from sqlalchemy import Column, Integer, String, Float, BLOB, DateTime

# %%
engine = create_engine('mysql://root:root@localhost:3306/kiva')

# %%
# Create both the Surfer and Board tables within the database
Base.metadata.create_all(engine)

# To push the objects made and query the server we use a Session object
from sqlalchemy.orm import Session
session = Session(bind=engine)

# %%
loans.head()
# Out:
#    Unnamed: 0  loan_id  status  activity_name  sector_name  \
# 0           0   657307  funded  General Store       Retail
# 1           1   656933  funded        Farming  Agriculture
# 2           2   659605  funded        Farming  Agriculture
# 3           3   660240  funded    Agriculture  Agriculture
# 4           4   661960  funded        Farming  Agriculture
#
#                                             loan_use country_code  \
# 0   to buy additional inventories for her sari-sa...           PH
# 1   to buy organic fertilizer and agrochemical pr...           PH
# 2  to buy organic pesticides and a new variety of...           PH
# 3  to finance farm maintenance and fertilization ...           PH
# 4                     to buy fertilizer for her farm           PH
#
#   country_name  partner_id          posted_time       ...         \
# 0  Philippines       126.0  2014-01-15 02:23:45       ...
# 1  Philippines       123.0  2014-01-14 05:46:21       ...
# ...

# %%
loan_records = loans.to_dict(orient='records')

# %%
class Loans(Base):
    __tablename__ = 'loans'
    __table_args__ = {'extend_existing': True} 
    
    loan_id = Column(Integer, primary_key=True)
    status  = Column(String(50))
    sector_name = Column(String(50))
    activity_name = Column(String(50))
    country_code = Column(String(3))
    country_name = Column(String(50))
    posted_time = Column(DateTime)
    disburse_time = Column(DateTime)
    raised_time = Column(DateTime)
    lender_term = Column(Integer)
    num_lenders_total = Column(Integer)
    repayment_interval = Column(String(50))
    shortage_fund = Column(Float)
    female_count = Column(Integer)
    male_count = Column(Integer)
    borrower_count = Column(Integer)
    funded_amount_usd = Column(Float)
    loan_amount_usd = Column(Float)
    
    
    
    def __init__(self,data):
        print(data['loan_id'])
        self.loan_id = data['loan_id']
        self.status = data['status']
        self.sector_name = data['sector_name']
        self.activity_name = data['activity_name']
        self.country_code = data['country_code']
        self.country_name = data['country_name']
        self.posted_time = data['posted_time']
        self.disburse_time = data['disburse_time']
        self.raised_time = data['raised_time']
        self.lender_term = data['lender_term']
        self.num_lenders_total = data['num_lenders_total']
        self.repayment_interval = data['repayment_interval']
        self.shortage_fund = data['shortage_fund']
        self.female_count = data['female_count']
        self.male_count = data['male_count']
        self.borrower_count = data['borrower_count']
        self.funded_amount_usd = data['funded_amount_usd']
        self.loan_amount_usd = data['loan_amount_usd']
# Out:
# C:\Users\ssank\Anaconda3\envs\py36\lib\site-packages\sqlalchemy\ext\declarative\clsregistry.py:120: SAWarning: This declarative base already contains a class with the same class name and module name as __main__.Loans, and will be replaced in the string-lookup table.
#   item.__name__

# %%
for n in range(0,len(loan_records)-1000,1000):
    loan_objects = [Loans(x) for x in loan_records[n:n+1000]]
    session.bulk_save_objects(loan_objects)
    session.commit()
# Out:
# 657307
# 656933
# 659605
# 660240
# 661960
# 664719
# 664242
# 956960
# 956996
# 955438
# 957461
# 959145
# 961209
# 961442
# 419129
# 420848
# 421802
# 1153825
# 1156076
# 1156276
# 252537
# 253044
# 808452
# 662304
# 956406
# 959640
# 959908
# 961094
# 961916
# 962630
# 963282
# 419562
# 419644
# 422210
# 1154491
# 1155527
# 1157252
# 1157257
# 254067
# 254413
# 707450
# 732296
# 1202375
# 659740
# 661278
# 664039
# 958910
# 962723
# 420439
# 420658
# 420778
# 1153644
# 1153678
# 1155367
# 1157277
# 1157285
# 1157423
# 1157809
# 1158933
# 1159313
# 252465
# 1155152
# 252002
# 699882
# 732829
# 741226
# 1190684
# 659272
# 661804
# 956754
# 956855
# 957748
# 957086
# 958971
# 1156915
# 1157291
# 1158514
# 252624
# 701681
# 663221
# 661777
# 663729
# 664854
# 955388
# 956445
# 957692
# 962440
# 420786
# 1157608
# 1158435
# 1158760
# 253767
# 776058
# 808515
# 956779
# 960385
# 961975
# 963208
# 416398
# 419535
# 420663
# 423249
# 1155122
# 1158610
# 671721
# 703415
# 656910
# 659097
# ...
